# %% [markdown]
# <a href="https://colab.research.google.com/github/hugo12xx/memoria/blob/main/Matriz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('primera.csv', sep=';')
data2 = pd.read_csv('2.csv', sep=';')
data3 = pd.read_csv('3.csv', sep=';')

total = pd.read_csv('probatotal.csv', sep=';')

# %%
from numpy import *

where_are_NaNs = isnan(data)
data[where_are_NaNs] = 0
print (data)
# Out:
#       0         1        2         3
# 0   0.0  0.173347  0.00000  0.197422
# 1   0.0  0.227215  0.09612  0.069158
# 2   0.0  0.072674  0.10119  0.000000
# 3   0.0  0.000000  0.00000  0.000000
# 4   0.0  0.000000  0.00000  0.000000
# ..  ...       ...      ...       ...
# 95  0.0  0.000000  0.00000  0.000000
# 96  0.0  0.000000  0.00000  0.000000
# 97  0.0  0.000000  0.00000  0.000000
# 98  0.0  0.000000  0.00000  0.000000
# 99  0.0  0.000000  0.00000  0.000000
#
# [100 rows x 4 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (10,10))

#mapa1= sns.heatmap(probatotal,cmap="YlOrRd")
#valores_q1=valores_q1/100

ax=sns.heatmap(data, cmap='YlOrRd')  
plt.show()
#figure =mapa1.get_figure()
figure.savefig('mapa1.png',dpi=400)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from pylab import savefig
plt.figure(figsize = (10,10))
mapa1= sns.heatmap(data2,cmap="YlOrRd")
figure =mapa1.get_figure()
figure.savefig('mapa1.png',dpi=400)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from pylab import savefig
plt.figure(figsize = (10,10))
mapa1= sns.heatmap(data3,cmap="YlOrRd")
figure =mapa1.get_figure()
figure.savefig('mapa1.png',dpi=400)

# %%
plt.figure(figsize = (10,10))
#mapa1= sns.heatmap(probatotal,cmap="YlOrRd")
#, annot=True
ax=sns.heatmap(total, vmin=0 , vmax=1, cmap='YlOrRd')  
plt.show()
figure =mapa1.get_figure()
figure.savefig('mapa1.png',dpi=400)
